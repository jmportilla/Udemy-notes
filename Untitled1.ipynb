# %%
import pandas as pd

# %%
# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats librayr from numpy
from scipy import stats

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

data = np.random.randn(100)

# %%
plt.hist(data,bins=50)
# Out:
# (array([ 2.,  1.,  0.,  0.,  1.,  0.,  1.,  5.,  2.,  2.,  2.,  2.,  6.,
#          3.,  7.,  2.,  2.,  4.,  1.,  1.,  3.,  1.,  3.,  4.,  7.,  0.,
#          4.,  5.,  4.,  3.,  4.,  2.,  3.,  2.,  1.,  0.,  1.,  2.,  0.,
#          0.,  2.,  0.,  1.,  1.,  0.,  0.,  1.,  0.,  1.,  1.]),
#  array([-2.13160015, -2.03530678, -1.93901342, -1.84272006, -1.74642669,
#         -1.65013333, -1.55383996, -1.4575466 , -1.36125324, -1.26495987,
#         -1.16866651, -1.07237314, -0.97607978, -0.87978642, -0.78349305,
#         -0.68719969, -0.59090632, -0.49461296, -0.3983196 , -0.30202623,
#         -0.20573287, -0.10943951, -0.01314614,  0.08314722,  0.17944059,
#          0.27573395,  0.37202731,  0.46832068,  0.56461404,  0.66090741,
#          0.75720077,  0.85349413,  0.9497875 ,  1.04608086,  1.14237423,
#          1.23866759,  1.33496095,  1.43125432,  1.52754768,  1.62384104,
#          1.72013441,  1.81642777,  1.91272114,  2.0090145 ,  2.10530786,
#          2.20160123,  2.29789459,  2.39418796,  2.49048132,  2.58677468,
#          2.68306805]),
#  <a list of 50 Patch objects>)

# %%
sns.distplot(data)
